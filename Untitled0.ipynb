# %% [markdown]
# <a href="https://colab.research.google.com/github/nijah465/learning.python/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
students_age = 25+
# Out:
# Hello World

# %%
temp_1 = float(input("Temperature in Celcius"))
formula = input("convert to:")
def conversion():
  if formula == "farenheit":
    print(9/5 * temp_1 + 32)
  else:
    print("check for spelling")
conversion()
# Out:
# Temperature in Celcius32
# convert to:farenheit
# 89.6

# %%
temp_1 = float(input("Temperature in Celcius"))
result = (9/5*temp_1 + 32)
print(result)
# Out:
# Temperature in Celcius22
# 71.6
